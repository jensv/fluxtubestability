# %%
from scipy.integrate import ode
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('poster')

# %%
def newcomb_der(r, y):
    y_prime = np.empty(2)
    y_prime[0] = y[1]/(100.*r)
    y_prime[1] = y[0]*0.1*r
    return y_prime

# %%
integrator = ode(newcomb_der)
integrator.set_integrator('dopri5')
init = [0., 1.]
integrator.set_initial_value(init, 0.001)
r = np.linspace(0.001, 1., 100)
results = np.zeros((2, r.size))
results[:,0] = init
for i, position in enumerate(r[1:]):
    integrator.integrate(position)
    results[:, i+1] = integrator.y

# %%
results
# Out:
# array([[ 0.        ,  0.02406126,  0.03053144,  0.03442747,  0.03722404,
#          0.03940701,  0.0411978 ,  0.04271608,  0.04403394,  0.04519818,
#          0.04624091,  0.04718511,  0.04804781,  0.04884196,  0.04957766,
#          0.05026294,  0.05090426,  0.05150692,  0.05207533,  0.05261316,
#          0.05312355,  0.05360915,  0.05407227,  0.0545149 ,  0.05493876,
#          0.0553454 ,  0.05573616,  0.05611222,  0.05647466,  0.05682444,
#          0.0571624 ,  0.05748931,  0.05780589,  0.05811276,  0.0584105 ,
#          0.05869964,  0.05898066,  0.05925401,  0.05952009,  0.05977929,
#          0.06003194,  0.06027838,  0.0605189 ,  0.06075378,  0.06098327,
#          0.06120763,  0.06142707,  0.06164181,  0.06185204,  0.06205796,
#          0.06225972,  0.06245751,  0.06265147,  0.06284175,  0.06302848,
#          0.0632118 ,  0.06339183,  0.06356868,  0.06374247,  0.06391331,
#          0.06408128,  0.06424648,  0.06440901,  0.06456895,  0.06472638,
# ...

# %%
plt.plot(r, results[0])

# %%
plt.plot(r, results[1]/4.)

# %%
xi_prime_prime = np.diff(results[1]/4.)/np.diff(r)

# %%
4.*xi_prime_prime-5.*results[0,1:]
# Out:
# array([-0.12029466, -0.15261205, -0.17205153, -0.18598961, -0.19685688,
#        -0.20576097, -0.21330073, -0.21983687, -0.22560358, -0.23076153,
#        -0.23542578, -0.23968156, -0.24359376, -0.24721291, -0.25057917,
#        -0.25372495, -0.25667682, -0.25945678, -0.26208332, -0.26457207,
#        -0.26693639, -0.2691878 , -0.27133627, -0.27339051, -0.27535817,
#        -0.277246  , -0.27905999, -0.28080549, -0.28248727, -0.28410963,
#        -0.28567645, -0.28719122, -0.28865714, -0.29007711, -0.29145377,
#        -0.29278955, -0.29408668, -0.29534722, -0.29657304, -0.29776589,
#        -0.29892741, -0.30005908, -0.30116231, -0.30223839, -0.30328854,
#        -0.30431389, -0.3053155 , -0.30629437, -0.30725142, -0.30818754,
#        -0.30910355, -0.31000022, -0.31087829, -0.31173844, -0.31258134,
#        -0.3134076 , -0.31421781, -0.31501251, -0.31579224, -0.3165575 ,
#        -0.31730876, -0.31804647, -0.31877108, -0.31948297, -0.32018256,
# ...
