# %%
from __future__ import print_function, unicode_literals, division
from __future__ import absolute_import
from future import standard_library, utils
from future.builtins import (ascii, bytes, chr, dict, filter, hex, input,
                             int, map, next, oct, open, pow, range, round,
                             str, super, zip)

# %%
import numpy as np
import sys
sys.path.append('..')
sys.path.append('../../../provenance_scripts/')
import skin_core_scanner_simple as scss
reload(scss)
import equil_solver as es
reload(es)
import newcomb_simple as new
reload(new)
import external_stability as ext
reload(ext)
import newcomb_init as init
reload(init)
import analytic_condition as ac
reload(ac)

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
sns.set_context('poster')

import lambda_k_plotting_simple as plot
reload(plot)
# Out:
# <module 'lambda_k_plotting_simple' from '../lambda_k_plotting_simple.py'>

# %% [markdown]
# # $\epsilon=1.1$

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-03-14-18/meshes.npz', 
                            1.1, 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True,
                            label_pos=[(1.9, 1.0), (2.6, 1.1), (2.6, 0.9), (1.5,0.2)],
                            interpolate=False)

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-03-14-18/meshes.npz', 
                            1.1, 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True,
                            label_pos=None,
                            interpolate=False)

# %% [markdown]
# # $\epsilon = 0.9$

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-03-14-22/meshes.npz', 
                            0.9, 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True,
                            label_pos=[(1.0, 1.), (1.5, 1.0), (1.7, 1.0)],
                            interpolate=False)

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-03-14-22/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False,
                            label_pos=[(1.0, 1.), (1.5, 1.0), (1.7, 1.0)],
                            interpolate=False)

# %% [markdown]
# # $\epsilon = 0.6$

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-03-14-37/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False,
                            label_pos=[(1.0, 1.), (1.5, 1.0), (1.7, 1.0)],
                            interpolate=False)

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-03-14-37/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False,
                            label_pos=[(1.0, 1.), (1.5, 1.0), (1.7, 1.0)],
                            interpolate=True)

# %% [markdown]
# # $\epsilon=0.5$

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-04-20-18/meshes.npz', 
                            0.5, 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True,
                            label_pos=[(1.0, 1.), (1.5, 1.0), (1.7, 1.0)],
                            interpolate=False)

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-04-20-18/meshes.npz', 
                            0.5, 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True,
                            label_pos=None,
                            interpolate=False)
# Out:
# test

# %% [markdown]
# # $\epsilon = 0.1$

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-04-20-39/meshes.npz', 
                            0.1, 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True,
                            label_pos=[(1.0, 1.1), (1.2, 0.9), (1.7, 0.8)],
                            interpolate=False)
# Out:
# test

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-04-20-39/meshes.npz', 
                            0.1, 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True,
                            label_pos=None,
                            interpolate=False)
# Out:
# test
