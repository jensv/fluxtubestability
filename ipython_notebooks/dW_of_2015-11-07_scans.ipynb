# %%
from __future__ import print_function, unicode_literals, division
from __future__ import absolute_import
from future import standard_library, utils
from future.builtins import (ascii, bytes, chr, dict, filter, hex, input,
                             int, map, next, oct, open, pow, range, round,
                             str, super, zip)

# %%
import numpy as np
import sys
sys.path.append('..')
sys.path.append('../../../provenance_scripts/')
import skin_core_scanner_simple as scss
reload(scss)
import equil_solver as es
reload(es)
import newcomb as new
reload(new)
import lambda_k_plotting_simple as plot
reload(plot)
import analytic_condition as ac
reload(ac)

 
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import SymLogNorm, BoundaryNorm
from matplotlib.ticker import FormatStrFormatter
import seaborn as sns
sns.set_style('ticks')
sns.set_context('poster')

# %% [markdown]
# Scan without jacobian

# %%
plot.plot_lambda_k_space_dw('../../output/2015-11-08-07-52/meshes.npz', 
                            0.1, 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False)

# %% [markdown]
# # Scan without diagnose and bdf

# %%
plot.plot_lambda_k_space_dw('../../output/2015-11-07-16-43/meshes.npz', 
                            0.1, 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False)

# %%
plot.plot_lambda_k_space_dw('../../output/2015-11-07-16-43/meshes.npz', 0.1, 'ep12-m1', 
                            mode_to_plot='m_0', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                        0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False)

# %%
plot.plot_lambda_k_space_dw('../../output/2015-11-07-17-03/meshes.npz', 
                            0.1, 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False)

# %% [markdown]
# # Scans with diagnose

# %%
plot.plot_lambda_k_space_dw('../../output/2015-11-07-17-33/meshes.npz', 
                            0.1, 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False)

# %% [markdown]
# # Scans with vode

# %%
plot.plot_lambda_k_space_dw('../../output/2015-11-07-18-03/meshes.npz', 
                            0.1, 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False)

# %% [markdown]
# # Scans with vode bdf

# %%
plot.plot_lambda_k_space_dw('../../output/2015-11-07-18-28/meshes.npz', 
                            0.1, 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False)

# %%
ac.condition_map_variable_delta('../../output/2015-11-07-18-28/meshes.npz',
                                mode=0, epsilon=0.1)

# %%
plot.plot_lambda_k_space_dw('../../output/2015-11-07-18-44/meshes.npz', 
                            0.1, 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=False)

# %%
ac.condition_map_variable_delta('../../output/2015-11-07-18-44/meshes.npz',
                                mode=0, epsilon=1.)
