# %% [markdown]
# # Plot profiles with $j_\theta$

# %%
from __future__ import print_function, unicode_literals, division
from __future__ import absolute_import
from future import standard_library, utils
from future.builtins import (ascii, bytes, chr, dict, filter, hex, input,
                             int, map, next, oct, open, pow, range, round,
                             str, super, zip)

# %%
import numpy as np
import sys
sys.path.append('..')
sys.path.append('../../../provenance_scripts/')
import equil_solver as es
reload(es)

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('poster')
sns.set_style('whitegrid')
import diagnostic_plots
reload(diagnostic_plots)
# Out:
# <module 'diagnostic_plots' from '../diagnostic_plots.pyc'>

# %% [markdown]
# # Smooth Core Skin with constant $j_\theta$

# %%
profile = es.UnitlessSmoothedCoreSkinLinearBz(core_radius_norm=0.6, 
                                              transition_width_norm=0.175, 
                                              skin_width_norm=0.1,
                                              k_bar=1.0,
                                              epsilon=0.5,
                                              lambda_bar=2.5,
                                              b_z_factor=0.8)

# %%
'j_theta' in splines.keys()
# Out:
# True

# %%
diagnostic_plots.plot_all_profiles_suydam(profile, normalize=True)
# Out:
# true

# %%
np.where(r>0.5)[0][0]
# Out:
# 125

# %% [markdown]
# # Smooth Core Skin with smooth $j_\theta$

# %%
profile = es.UnitlessSmoothedCoreSkinSmoothJTheta(core_radius_norm=0.6, 
                                                  transition_width_norm=0.175, 
                                                  skin_width_norm=0.1,
                                                  k_bar=1.0,
                                                  epsilon=0.5,
                                                  lambda_bar=2.5,
                                                  j_theta_peak=1.5,
                                                  j_theta_start=0.6,
                                                  j_theta_peak_pos=0.95)

# %%
diagnostic_plots.plot_all_profiles_suydam(profile)
# Out:
# true

# %%
profile = es.UnitlessExponentialDecaySkin(
                                                  k_bar=1.0,
                                                  epsilon=0.5,
                                                  lambda_bar=2.5)

# %%
diagnostic_plots.plot_all_profiles_suydam(profile)
# Out:
# false

# %%
profile = es.UnitlessSmoothedCoreSkin(k_bar=1.0,
                                    epsilon=0.5,
                                    lambda_bar=2.5)

# %%
diagnostic_plots.plot_all_profiles_suydam(profile)
# Out:
# false

# %%
profile = es.UnitlessSmoothedCoreSkin(k_bar=2.0,
                                      epsilon=0.1,
                                      lambda_bar=3.5,
                                      core_radius_norm=0.01,
                                      transition_width_norm=0.48,
                                      skin_width_norm=0.01)

# %%
diagnostic_plots.plot_all_profiles_suydam(profile)
# Out:
# false

# %%
profile.beta_0()
# Out:
# 8.4773933047936687

# %%
profile = es.UnitlessSmoothedCoreSkin(k_bar=2.0,
                                      epsilon=0.1,
                                      lambda_bar=0.1,
                                      core_radius_norm=0.01,
                                      transition_width_norm=0.48,
                                      skin_width_norm=0.01)

# %%
diagnostic_plots.plot_all_profiles_suydam(profile)
# Out:
# false

# %%
profile = es.UnitlessSmoothedCoreSkin(k_bar=2.0,
                                      epsilon=0.1,
                                      lambda_bar=020,
                                      core_radius_norm=0.01,
                                      transition_width_norm=0.48,
                                      skin_width_norm=0.01)

# %%
diagnostic_plots.plot_all_profiles_suydam(profile)
# Out:
# false
