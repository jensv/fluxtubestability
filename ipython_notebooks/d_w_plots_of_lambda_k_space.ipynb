# %% [markdown]
# # $\delta W$ of the instabilties in the $\bar{\lambda}$ and $\bar{k}$ space

# %% [markdown]
# In this notebook I plot the $\delta W$ of the instabilties so I can see how "strong" the instabilties are. Some may be so close to zero that they could be considered marginal.
# I will mark points at which I can not succesfully integrate in red.

# %% [markdown]
# ## Import modules

# %%
from __future__ import print_function, unicode_literals, division
from __future__ import absolute_import
from future import standard_library, utils
from future.builtins import (ascii, bytes, chr, dict, filter, hex, input,
                             int, map, next, oct, open, pow, range, round,
                             str, super, zip)

# %%
import numpy as np
import sys
sys.path.append('..')
sys.path.append('../../../provenance_scripts/')
import skin_core_scanner_simple as scss
reload(scss)
import equil_solver as es
reload(es)
import newcomb as new
reload(new)
import lambda_k_plotting_simple as plot
reload(plot)

 
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import SymLogNorm, BoundaryNorm
from matplotlib.ticker import FormatStrFormatter
import seaborn as sns
sns.set_style('ticks')
sns.set_context('poster')

# %%
sns.palplot(sns.blend_palette(['orange','white'], 5))

# %%
sns.palplot(sns.blend_palette([sns.xkcd_rgb["dandelion"], sns.xkcd_rgb["white"]], 5))

# %%
sns.palplot(sns.diverging_palette(73, 180, s=99, l=85, sep=1, n=9))

# %%
sns.palplot(sns.diverging_palette(49, 181, s=99, l=78, sep=1, n=9))

# %% [markdown]
# # $\epsilon=0.11$

# %%
plot.plot_lambda_k_space_dw('../../output/2015-02-22-17-51/meshes.npz', 0.11, 'ep12-m1', 
                            mode_to_plot='m_neg_1', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                            0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True)
# Out:
# /home/jensv/anaconda/lib/python2.7/site-packages/matplotlib/text.py:52: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if rotation in ('horizontal', None):
# /home/jensv/anaconda/lib/python2.7/site-packages/matplotlib/text.py:54: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif rotation == 'vertical':

# %%
plot.plot_lambda_k_space_dw('../../output/2015-02-22-17-51/meshes.npz', 0.11, 'ep12-m1', 
                            mode_to_plot='m_0', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                        0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True)

# %% [markdown]
# # $\epsilon = 0.1$

# %%
plot.plot_lambda_k_space_dw('../../output/2015-03-27-21-25/meshes.npz', 0.1, 'ep12-m1', 
                            mode_to_plot='m_neg_1', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                            0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True)

# %%
test_data = np.load('../../output/2015-03-27-21-25/meshes.npz')
test_lambda = test_data['lambda_a_mesh']
test_k = test_data['k_a_mesh']
test_suydam = test_data['delta_m_neg_1'] 
colors = sns.light_palette('yellow', n_colors=6, reverse=True, as_cmap=True)
plt.contourf(test_lambda, test_k, test_suydam, cmap=colors)
cbar = plt.colorbar(label=r'$\delta W$')
cbar.set_label(label=r'$\delta W$', size=45, rotation=0, labelpad=30)
plt.contour(test_lambda, test_k, test_suydam, colors='grey')

axes = plt.gca()
plt.setp(axes.get_xticklabels(), fontsize=40)
plt.setp(axes.get_yticklabels(), fontsize=40)
plt.ylabel(r'$\bar{k}$', fontsize=45, rotation='horizontal', labelpad=30)
plt.xlabel(r'$\bar{\lambda}$', fontsize=45)
cbar.ax.tick_params(labelsize=40)
sns.despine(ax=axes)
plt.tight_layout()

# %%
plot.plot_lambda_k_space_dw('../../output/2015-02-16-23-31/meshes.npz', 0.1, 'ep12-m1', 
                            mode_to_plot='m_0', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                        0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True)

# %%
test_data = np.load('../../output/2015-02-16-23-31/meshes.npz')
test_lambda = test_data['lambda_a_mesh']
test_k = test_data['k_a_mesh']
test_suydam = test_data['suydam_m_neg_1'] 
plt.contourf(test_lambda, test_k, test_suydam)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x7f1045837f80>

# %%
test_data = np.load('../../output/2015-03-27-21-25/meshes.npz')
test_lambda = test_data['lambda_a_mesh']
test_k = test_data['k_a_mesh']
test_suydam = test_data['delta_m_0'] 
colors = sns.light_palette('orange', n_colors=6, reverse=True, as_cmap=True)
plt.contourf(test_lambda, test_k, test_suydam, cmap=colors)
cbar = plt.colorbar(label=r'$\delta W$')
cbar.set_label(label=r'$\delta W$', size=45, rotation=0, labelpad=30)
plt.contour(test_lambda, test_k, test_suydam, colors='grey')

axes = plt.gca()
plt.setp(axes.get_xticklabels(), fontsize=40)
plt.setp(axes.get_yticklabels(), fontsize=40)
plt.ylabel(r'$\bar{k}$', fontsize=45, rotation='horizontal', labelpad=30)
plt.xlabel(r'$\bar{\lambda}$', fontsize=45)
cbar.ax.tick_params(labelsize=40)
sns.despine(ax=axes)
plt.tight_layout()

# %% [markdown]
# # $\epsilon$ = 0.5

# %%
plot.plot_lambda_k_space_dw('../../output/2015-02-17-00-35/meshes.npz', 0.5, 'ep12-m1', 
                            mode_to_plot='m_neg_1', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                            0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True, label_pos=((1.5, 1.2), (1.7, 1.2), (2.2, 1.2),
                                                                               (1.5, 0.01)))

# %%
plot.plot_lambda_k_space_dw('../../output/2015-02-17-00-35/meshes.npz', 0.5, 'ep12-m1', 
                            mode_to_plot='m_0', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                        0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True, label_pos=((-10, -10),(2.5, 0.6)))

# %%
#levels = [-240, -1, -0.1, 0.1,  1, 80]
levels = None
test_data = np.load('../../output/2015-03-27-21-53/meshes.npz')
test_lambda = test_data['lambda_a_mesh']
test_k = test_data['k_a_mesh']
test_delta = test_data['delta_m_0'] 

#print(test_delta[test_delta > 1])
test_delta = np.clip(test_delta, -1.5, 1)

#print(np.sum(test_delta < -1))
#test_delta = test_delta/np.nanmax(np.abs(test_delta))

colors = sns.light_palette('orange', n_colors=6, reverse=True, as_cmap=True)

if levels:
    plt.contourf(test_lambda, test_k, test_delta, cmap=colors, levels=levels)
else:
    plt.contourf(test_lambda, test_k, test_delta, cmap=colors)
    
cbar = plt.colorbar(label=r'$\delta$')
cbar.set_label(label=r'$\delta$', size=45, rotation=0, labelpad=30)

if levels:
    plt.contour(test_lambda, test_k, test_delta, colors='grey', levels=levels)
else:
    plt.contour(test_lambda, test_k, test_delta, colors='grey')
    
plt.ylim(0.01, 1.5)
plt.xlim(0.01, 3.0)
axes = plt.gca()
axes.set_axis_bgcolor(sns.xkcd_rgb['grey'])
plt.setp(axes.get_xticklabels(), fontsize=40)
plt.setp(axes.get_yticklabels(), fontsize=40)
plt.ylabel(r'$\bar{k}$', fontsize=45, rotation='horizontal', labelpad=30)
plt.xlabel(r'$\bar{\lambda}$', fontsize=45)
cbar.ax.tick_params(labelsize=40)
sns.despine(ax=axes)
plt.tight_layout()

# %%
test_data = np.load('../../output/2015-02-17-00-35/meshes.npz')
test_lambda = test_data['lambda_a_mesh']
test_k = test_data['k_a_mesh']
test_suydam = test_data['suydam_m_neg_1'] 
plt.contourf(test_lambda, test_k, test_suydam)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x000000001AA88108>

# %% [markdown]
# # $\epsilon=1.0$

# %%
plot.plot_lambda_k_space_dw('../../output/2015-02-17-02-04/meshes.npz', 1.0, 'ep12-m1', 
                            mode_to_plot='m_neg_1', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                            0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True, analytic_compare=True)

# %%
plot.plot_lambda_k_space_dw('../../output/2015-02-17-02-04/meshes.npz', 1.0, 'ep12-m1', 
                            mode_to_plot='m_0', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                        0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True)

# %%
#levels = [-240, -1, -0.1, 0.1,  1, 80]
levels = None
test_data = np.load('../../output/2015-02-17-02-04/meshes.npz')
test_lambda = test_data['lambda_a_mesh']
test_k = test_data['k_a_mesh']
test_delta = test_data['delta_m_0'] 

#print(test_delta[test_delta > 1])
test_delta = np.clip(test_delta, -1.5, 1)

#print(np.sum(test_delta < -1))
#test_delta = test_delta/np.nanmax(np.abs(test_delta))

colors = sns.light_palette('orange', n_colors=6, reverse=True, as_cmap=True)

if levels:
    plt.contourf(test_lambda, test_k, test_delta, cmap=colors, levels=levels)
else:
    plt.contourf(test_lambda, test_k, test_delta, cmap=colors)
    
cbar = plt.colorbar(label=r'$\delta$')
cbar.set_label(label=r'$\delta$', size=45, rotation=0, labelpad=30)

if levels:
    plt.contour(test_lambda, test_k, test_delta, colors='grey', levels=levels)
else:
    plt.contour(test_lambda, test_k, test_delta, colors='grey')
    
plt.ylim(0.01, 1.5)
plt.xlim(0.01, 3.0)
axes = plt.gca()
axes.set_axis_bgcolor(sns.xkcd_rgb['grey'])
plt.setp(axes.get_xticklabels(), fontsize=40)
plt.setp(axes.get_yticklabels(), fontsize=40)
plt.ylabel(r'$\bar{k}$', fontsize=45, rotation='horizontal', labelpad=30)
plt.xlabel(r'$\bar{\lambda}$', fontsize=45)
cbar.ax.tick_params(labelsize=40)
sns.despine(ax=axes)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-e35c0f4c992c> in <module>()
#       4 test_lambda = test_data['lambda_a_mesh']
#       5 test_k = test_data['k_a_mesh']
# ----> 6 test_delta = test_data['delta_m_0']
#       7
#       8 #print(test_delta[test_delta > 1])
#
# /home/jensv/anaconda/lib/python2.7/site-packages/numpy/lib/npyio.pyc in __getitem__(self, key)
#     253                 return self.zip.read(key)
#     254         else:
# --> 255             raise KeyError("%s is not a file in the archive" % key)
#     256
#     257     def __iter__(self):
#
# KeyError: u'delta_m_0 is not a file in the archive'

# %%
test_data = np.load('../../output/2015-02-17-02-04/meshes.npz')
test_lambda = test_data['lambda_a_mesh']
test_k = test_data['k_a_mesh']
test_suydam = test_data['suydam_m_neg_1'] 
plt.contourf(test_lambda, test_k, test_suydam)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x000000001FAAE188>

# %%
plot.plot_lambda_k_space_dw('../../output/2015-02-27-10-28/meshes.npz', 'ep12-m1', 
                            mode_to_plot='m_neg_1', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                            0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True)

# %%
plot.plot_lambda_k_space_dw('../../output/2015-02-27-10-28/meshes.npz', 'ep12-m1', 
                            mode_to_plot='m_0', levels=[-1, -1e-1, -1e-2, -1e-3, 
                                                        0, 1e-3, 1e-2, 1e-1, 1], 
                            floor_norm=True)
