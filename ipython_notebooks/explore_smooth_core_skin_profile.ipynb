# %% [markdown]
# # Examine Core & Skin Current Profiles

# %% [markdown]
# In this notebook I will test the additions I have made to equil_solver.py so that I can create core and skin current profiles with smooth transitions. The transition was suggested by Alan Glasser.

# %% [markdown]
# ## Python 3.x compatability

# %%
from __future__ import print_function, unicode_literals, division
from __future__ import absolute_import
from future import standard_library, utils
from future.builtins import (ascii, bytes, chr, dict, filter, hex, input,
                             int, map, next, oct, open, pow, range, round,
                             str, super, zip)

# %% [markdown]
# ## Load plotting, numerical and equil_solver modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('poster')

import numpy as np
import scipy.constants as consts
import scipy.integrate as integ
import sys
sys.path.append('..')

# %%
import equil_solver as es
reload(es)
# Out:
# <module 'equil_solver' from '..\equil_solver.pyc'>

# %% [markdown]
# ## Look at how $\epsilon$ varies $j_{z}$, $B_{\theta}$, $p$ profiles

# %% [markdown]
# ### Create Profiles

# %%
ep_05_profile = es.SmoothedCoreSkin(mu_0=1., epsilon=0.5, lambda_bar=0.5, k=1., j_core=0.1)
ep_07_profile = es.SmoothedCoreSkin(mu_0=consts.mu_0, epsilon=0.7, lambda_bar=1.0, k=1., j_core=0.1)
ep_10_profile = es.SmoothedCoreSkin(mu_0=1., epsilon=1.0, lambda_bar=1.0, k=1., j_core=0.1)
ep_12_profile = es.SmoothedCoreSkin(mu_0=1., epsilon=1.2, lambda_bar=1.0, k=1., j_core=0.1)

# %% [markdown]
# ### Get Splines

# %%
ep_02_splines = ep_05_profile.get_splines()
ep_05_splines = ep_07_profile.get_splines()
ep_10_splines = ep_10_profile.get_splines()
ep_12_splines = ep_12_profile.get_splines()

# %%
epsilon_labels = [0.5, 0.7, 1.0, 1.2]
r = np.linspace(0, 1, 1000)

# %% [markdown]
# ### Plot Axial Current

# %%
fig, axs = plt.subplots(1,4, figsize=(20,5), sharey=True)
axs[0].plot(r, ep_02_splines['j_z'](r))
axs[1].plot(r, ep_05_splines['j_z'](r))
axs[2].plot(r, ep_10_splines['j_z'](r))
axs[3].plot(r, ep_12_splines['j_z'](r))
    
axs[0].set_ylabel(r'$j_{z}$', fontsize=25)
for i, axis in enumerate(axs):
    axis.set_xlabel(r'$r$', fontsize=25)
    epsilon = epsilon_labels[i]
    axis.set_title(r'$\epsilon = $' + str(epsilon), fontsize=25)

# %% [markdown]
# ### Plot Azimuthal Field

# %%
fig, axs = plt.subplots(1,4, figsize=(20,5), sharey=True)
axs[0].plot(r, ep_02_splines['b_theta'](r))
axs[1].plot(r, ep_05_splines['b_theta'](r))
axs[2].plot(r, ep_10_splines['b_theta'](r))
axs[3].plot(r, ep_12_splines['b_theta'](r))
    
axs[0].set_ylabel(r'$B_{\theta}$', fontsize=25)
for i, axis in enumerate(axs):
    axis.set_xlabel(r'$r$', fontsize=25)
    epsilon = epsilon_labels[i]
    axis.set_title(r'$\epsilon = $' + str(epsilon), fontsize=25)

# %% [markdown]
# ### Plot Pressure Prime

# %%
fig, axs = plt.subplots(1,4, figsize=(20,5), sharey=True)
axs[0].plot(r, ep_02_splines['p_prime'](r))
axs[1].plot(r, ep_05_splines['p_prime'](r))
axs[2].plot(r, ep_10_splines['p_prime'](r))
axs[3].plot(r, ep_12_splines['p_prime'](r))
    
axs[0].set_ylabel(r'$p$', fontsize=25)
for i, axis in enumerate(axs):
    axis.set_xlabel(r'$r$', fontsize=25)
    epsilon = epsilon_labels[i]
    axis.set_title(r'$\epsilon = $' + str(epsilon), fontsize=25)

# %% [markdown]
# ### Plot Pressure

# %%
fig, axs = plt.subplots(1,4, figsize=(20,5), sharey=True)
axs[0].plot(r, ep_02_splines['pressure'](r))
axs[1].plot(r, ep_05_splines['pressure'](r))
axs[2].plot(r, ep_10_splines['pressure'](r))
axs[3].plot(r, ep_12_splines['pressure'](r))
    
axs[0].set_ylabel(r'$p$', fontsize=25)
for i, axis in enumerate(axs):
    axis.set_xlabel(r'$r$', fontsize=25)
    epsilon = epsilon_labels[i]
    axis.set_title(r'$\epsilon = $' + str(epsilon), fontsize=25)

# %% [markdown]
# ### Plot Safety Factor

# %%
fig, axs = plt.subplots(1,4, figsize=(20,5), sharey=True)
axs[0].plot(r, ep_02_splines['q'](r))
axs[1].plot(r, ep_05_splines['q'](r))
axs[2].plot(r, ep_10_splines['q'](r))
axs[3].plot(r, ep_12_splines['q'](r))
    
axs[0].set_ylabel(r'$q$', fontsize=25)
for i, axis in enumerate(axs):
    axis.set_xlabel(r'$r$', fontsize=25)
    epsilon = epsilon_labels[i]
    axis.set_title(r'$\epsilon = $' + str(epsilon), fontsize=25)

# %% [markdown]
# ## Look at how $\bar{\lambda}$ varies $q$ profiles

# %% [markdown]
# ### Create Profiles

# %%
lambda_050_profiles = es.SmoothedCoreSkin(mu_0=1., epsilon=0.2, lambda_bar=0.5, k=0.5, j_core=0.1)
lambda_150_profiles = es.SmoothedCoreSkin(mu_0=1., epsilon=0.2, lambda_bar=1.0, k=0.5, j_core=0.1)
lambda_250_profiles = es.SmoothedCoreSkin(mu_0=1., epsilon=0.2, lambda_bar=2.5, k=0.5, j_core=0.1)
lambda_350_profiles = es.SmoothedCoreSkin(mu_0=1., epsilon=0.2, lambda_bar=3.5, k=0.5, j_core=0.1)

# %% [markdown]
# ### Create Splines

# %%
lambda_050_splines = lambda_050_profiles.get_splines() 
lambda_100_splines = lambda_150_profiles.get_splines() 
lambda_250_splines = lambda_250_profiles.get_splines()
lambda_350_splines = lambda_350_profiles.get_splines()

# %%
lambda_labels = [0.50, 1.0, 2.5, 3.5]

# %% [markdown]
# ### Plot safety factor

# %%
fig, axs = plt.subplots(1,4, figsize=(20,5), sharey=True)
axs[0].plot(r, lambda_050_splines['q'](r))
axs[1].plot(r, lambda_100_splines['q'](r))
axs[2].plot(r, lambda_350_splines['q'](r))
axs[3].plot(r, lambda_350_splines['q'](r))
    
axs[0].set_ylabel(r'$q$', fontsize=25)
for i, axis in enumerate(axs):
    axis.set_xlabel(r'$r$', fontsize=25)
    lambda_label = lambda_labels[i]
    axis.set_title(r'$\bar{\lambda} = $' + str(lambda_label), fontsize=25)

# %%
lambda_100_splines['q'](r)[-1]
# Out:
# 0.9999982098624014

# %% [markdown]
# ## Look at how $\bar{k}$ varies $q$ profiles

# %% [markdown]
# ### Create Profiles

# %%
k_025_profiles = es.SmoothedCoreSkin(mu_0=1., epsilon=0.2, lambda_bar=1.0, k=0.25, j_core=0.001)
k_050_profiles = es.SmoothedCoreSkin(mu_0=1., epsilon=0.2, lambda_bar=1.0, k=0.5, j_core=0.001)
k_075_profiles = es.SmoothedCoreSkin(mu_0=1., epsilon=0.2, lambda_bar=1.0, k=0.75, j_core=0.001)
k_125_profiles = es.SmoothedCoreSkin(mu_0=1., epsilon=0.2, lambda_bar=1.0, k=1.25, j_core=0.001)

# %% [markdown]
# ### Create Splines

# %%
k_025_splines = k_025_profiles.get_splines()
k_050_splines = k_050_profiles.get_splines()
k_075_splines = k_075_profiles.get_splines()
k_125_splines = k_125_profiles.get_splines()

# %%
k_labels = [0.25, 0.5, 0.75, 1.25]

# %% [markdown]
# ### Plot safety factor

# %%
fig, axs = plt.subplots(1,4, figsize=(20,5), sharey=True)
axs[0].plot(r, k_025_splines['q'](r))
axs[1].plot(r, k_050_splines['q'](r))
axs[2].plot(r, k_075_splines['q'](r))
axs[3].plot(r, k_125_splines['q'](r))
    
axs[0].set_ylabel(r'$q$', fontsize=25)
for i, axis in enumerate(axs):
    axis.set_xlabel(r'$r$', fontsize=25)
    k_label = k_labels[i]
    axis.set_title(r'$k = $' + str(k_label), fontsize=25)

# %% [markdown]
# ## $\beta$ seems to be high. How does $\beta$ change with larger skin regions?

# %%
beta_default_profile = es.SmoothedCoreSkin(mu_0=0.01, epsilon=0.7, lambda_bar=1.0, k=1., j_core=0.01)
beta_elongated_profile = es.SmoothedCoreSkin(mu_0=0.01, epsilon=0.7, lambda_bar=1.0, k=1., j_core=0.01, core_radius=0.1, transition_width=0.1, skin_width=0.4)
beta_elongated_inverted_profile = es.SmoothedCoreSkin(mu_0=0.01, epsilon=1.2, lambda_bar=1.0, k=1., j_core=0.01, core_radius=0.1, transition_width=0.1, skin_width=0.4)
beta_low_lambda_profile = es.SmoothedCoreSkin(mu_0=0.01, epsilon=0.7, lambda_bar=0.1, k=1., j_core=0.01)

# %%
beta_default_splines = beta_default_profile.get_splines()
beta_elongated_splines = beta_elongated_profile.get_splines()
beta_elongated_inverted_splines = beta_elongated_inverted_profile.get_splines()
beta_low_lambda_splines = beta_low_lambda_profile.get_splines()

# %%
beta_default_beta_spl = beta_default_profile.get_beta(beta_default_profile.r)
beta_elongated_beta_spl = beta_elongated_profile.get_beta(beta_elongated_profile.r)
beta_elongated_inverted_beta_spl = beta_elongated_inverted_profile.get_beta(beta_elongated_inverted_profile.r)
beta_low_lambda_beta_spl = beta_low_lambda_profile.get_beta(beta_low_lambda_profile.r)

# %%
beta_labels = ['default', 'elongated', 'elongated inverted', 'low lambda']

# %%
fig, axs = plt.subplots(1, 4, figsize=(20,5), sharey=True)
axs[0].plot(r, beta_default_beta_spl(r))
axs[1].plot(r, beta_elongated_beta_spl(r))
axs[2].plot(r, beta_elongated_inverted_beta_spl(r))
axs[3].plot(r, beta_low_lambda_beta_spl(r))

    
axs[0].set_ylabel(r'$\beta$', fontsize=25)
for i, axis in enumerate(axs):
    axis.set_xlabel(r'$r$', fontsize=25)
    beta_label = beta_labels[i]
    axis.set_title(r'' + str(beta_label), fontsize=25)
