# %% [markdown]
# In this notebook I look at the results of the latest scans and for the first time compare the magnitude of $\delta W$ for the sausage and kink modes in regions where both are unstable to see if one mode dominates other the other.

# %%
from __future__ import print_function, unicode_literals, division
from __future__ import absolute_import
from future import standard_library, utils
from future.builtins import (ascii, bytes, chr, dict, filter, hex, input,
                             int, map, next, oct, open, pow, range, round,
                             str, super, zip)

# %%
import numpy as np
import sys
sys.path.append('..')
sys.path.append('../../../provenance_scripts/')
import skin_core_scanner_simple as scss
reload(scss)
import equil_solver as es
reload(es)
import newcomb_simple as new
reload(new)
import external_stability as ext
reload(ext)
import newcomb_init as init
reload(init)
import analytic_condition as ac
reload(ac)

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import seaborn as sns
sns.set_style('white')
sns.set_context('poster')

import lambda_k_plotting_simple as plot
reload(plot)
# Out:
# <module 'lambda_k_plotting_simple' from '../lambda_k_plotting_simple.py'>

# %% [markdown]
# # For $r_{skin}$=0.1

# %% [markdown]
# $\epsilon = 1.$

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-18-14-03/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            norm=True, analytic_compare=False,
                            log=True,
                            label_pos=None,
                            interpolate=False)

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-18-14-03/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            norm=True, analytic_compare=False, log=True,
                            label_pos=[(1.0, 1.), (1.5, 1.0), (1.7, 1.0)],
                            interpolate=False)

# %%
plot.sausage_kink_ratio('../../output/2016-01-18-14-03/meshes.npz',
                        xy_limits=None)

# %% [markdown]
# $\epsilon = 0.5$

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-18-14-08/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            norm=True, analytic_compare=False,
                            log=True,
                            label_pos=None,
plot.plot_lambda_k_space_dw('../../output/2016-01-18-14-08/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            norm=True, analytic_compare=False,
                            log=True,
                            label_pos=None,
                            interpolate=False)                            interpolate=False)

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-18-14-08/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            norm=True, analytic_compare=False,
                            log=True,
                            label_pos=None,
                            interpolate=False)

# %%
sausage_kink_ratio('../../output/2016-01-18-14-08/meshes.npz',
                   xy_limits=None)

# %% [markdown]
# $\epsilon = 0.1$

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-18-14-13/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_neg_1', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            norm=True, analytic_compare=False,
                            log=True,
                            label_pos=None,
                            interpolate=False)

# %%
plot.plot_lambda_k_space_dw('../../output/2016-01-18-14-13/meshes.npz', 
                            1., 'ep12-m1', mode_to_plot='m_0', 
                            levels=[-1, -1e-1, -1e-2, -1e-3, 
                                    0, 1e-3, 1e-2, 1e-1, 1], 
                            norm=True, analytic_compare=False,
                            log=True,
                            label_pos=None,
                            interpolate=False)

# %%
sausage_kink_ratio('../../output/2016-01-18-14-13/meshes.npz',
                   xy_limits=None)
